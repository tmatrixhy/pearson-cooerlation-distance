# %%
# !pip install ray
# Out:
# Collecting ray
#   Downloading https://files.pythonhosted.org/packages/ea/ed/ff896981d4ac684614236f73c1a20cde5f6cb0e2a590c182f62b22706ab4/ray-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (22.9MB)
#      |████████████████████████████████| 22.9MB 1.3MB/s
# Collecting aiohttp
#   Downloading https://files.pythonhosted.org/packages/7c/39/7eb5f98d24904e0f6d3edb505d4aa60e3ef83c0a58d6fe18244a51757247/aiohttp-3.6.2-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 31.0MB/s
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.6/dist-packages (from ray) (1.32.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray) (3.13)
# Collecting aioredis
#   Downloading https://files.pythonhosted.org/packages/b0/64/1b1612d0a104f21f80eb4c6e1b6075f2e6aba8e228f46f229cfd3fdac859/aioredis-1.3.1-py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 6.5MB/s
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from ray) (1.18.5)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Collecting aiohttp-cors
#   Downloading https://files.pythonhosted.org/packages/13/e7/e436a0c0eb5127d8b491a9b83ecd2391c6ff7dcd5548dfaec2080a2340fd/aiohttp_cors-0.7.0-py3-none-any.whl
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from ray) (0.8.0)
# Collecting redis<3.5.0,>=3.3.2
#   Downloading https://files.pythonhosted.org/packages/f0/05/1fc7feedc19c123e7a95cfc9e7892eb6cdd2e5df4e9e8af6384349c1cc3d/redis-3.4.1-py2.py3-none-any.whl (71kB)
#      |████████████████████████████████| 71kB 5.2MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from ray) (3.0.12)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from ray) (1.0.0)
# Collecting opencensus
#   Downloading https://files.pythonhosted.org/packages/8a/9c/d40e3408e72d02612acf247d829e3fa9ff15c59f7ad81418ed79962f8681/opencensus-0.7.10-py2.py3-none-any.whl (126kB)
#      |████████████████████████████████| 133kB 45.1MB/s
# Collecting py-spy>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/8e/a7/ab45c9ee3c4654edda3efbd6b8e2fa4962226718a7e3e3be6e3926bf3617/py_spy-0.3.3-py2.py3-none-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 36.6MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray) (3.12.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from ray) (2.23.0)
# Collecting gpustat
#   Downloading https://files.pythonhosted.org/packages/b4/69/d8c849715171aeabd61af7da080fdc60948b5a396d2422f1f4672e43d008/gpustat-0.6.0.tar.gz (78kB)
#      |████████████████████████████████| 81kB 8.0MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray) (2.6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.6/dist-packages (from ray) (7.1.2)
# Collecting colorful
#   Downloading https://files.pythonhosted.org/packages/b0/8e/e386e248266952d24d73ed734c2f5513f34d9557032618c8910e605dfaf6/colorful-0.5.4-py2.py3-none-any.whl (201kB)
#      |████████████████████████████████| 204kB 36.8MB/s
# Requirement already satisfied: google in /usr/local/lib/python3.6/dist-packages (from ray) (2.0.3)
# Collecting multidict<5.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/1a/95/f50352b5366e7d579e8b99631680a9e32e1b22adfa1629a8f23b1d22d5e2/multidict-4.7.6-cp36-cp36m-manylinux1_x86_64.whl (148kB)
#      |████████████████████████████████| 153kB 46.0MB/s
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (20.2.0)
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/01/c9/379b807a9c298b9694d0af8ee4260be7d40ab1a11fb9d4ae9e70b1e69d96/yarl-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (257kB)
#      |████████████████████████████████| 266kB 44.0MB/s
# Collecting idna-ssl>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (3.7.4.3)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio>=1.28.1->ray) (1.15.0)
# Collecting hiredis
#   Downloading https://files.pythonhosted.org/packages/ed/7d/6acf1c8d4f2fb327ff6feec000b4c56a20628fbe966a4c7cd16c0b80343c/hiredis-1.1.0-cp36-cp36m-manylinux2010_x86_64.whl (61kB)
#      |████████████████████████████████| 61kB 8.0MB/s
# Requirement already satisfied: google-api-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from opencensus->ray) (1.16.0)
# Collecting opencensus-context==0.1.1
#   Downloading https://files.pythonhosted.org/packages/2b/b7/720d4507e97aa3916ac47054cd75490de6b6148c46d8c2c487638f16ad95/opencensus_context-0.1.1-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray) (50.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->ray) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from gpustat->ray) (7.352.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (from gpustat->ray) (5.4.8)
# Collecting blessings>=1.6
#   Downloading https://files.pythonhosted.org/packages/03/74/489f85a78247609c6b4f13733cbf3ba0d864b11aa565617b645d6fdf2a4a/blessings-1.7-py3-none-any.whl
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google->ray) (4.6.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (1.52.0)
# Requirement already satisfied: google-auth<2.0dev,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (1.17.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (2018.9)
# Collecting contextvars; python_version >= "3.6" and python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (0.2.8)
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
#      |████████████████████████████████| 102kB 12.1MB/s
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (0.4.8)
# Building wheels for collected packages: gpustat, idna-ssl, contextvars
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-cp36-none-any.whl size=12622 sha256=9cbcb1cf5226166829862dec812c55707ad9a4e5d7951f8ffd0cfa2a8587af42
#   Stored in directory: /root/.cache/pip/wheels/48/b4/d5/fb5b7f1d040f2ff20687e3bad6867d63155dbde5a7c10f4293
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3161 sha256=314bcc8c165139ad4e08ca2a6cc828de86962a5978e782813ec9d00df8f2f641
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7666 sha256=2d8558e173caaa9e463f6ed61f32c8859aa4440b76b3a43a4be4eb76c891c4b4
#   Stored in directory: /root/.cache/pip/wheels/a5/7d/68/1ebae2668bda2228686e3c1cf16f2c2384cea6e9334ad5f6de
# Successfully built gpustat idna-ssl contextvars
# Installing collected packages: multidict, async-timeout, yarl, idna-ssl, aiohttp, hiredis, aioredis, colorama, aiohttp-cors, redis, immutables, contextvars, opencensus-context, opencensus, py-spy, blessings, gpustat, colorful, ray
# Successfully installed aiohttp-3.6.2 aiohttp-cors-0.7.0 aioredis-1.3.1 async-timeout-3.0.1 blessings-1.7 colorama-0.4.3 colorful-0.5.4 contextvars-2.4 gpustat-0.6.0 hiredis-1.1.0 idna-ssl-1.1.0 immutables-0.14 multidict-4.7.6 opencensus-0.7.10 opencensus-context-0.1.1 py-spy-0.3.3 ray-1.0.0 redis-3.4.1 yarl-1.6.0

# %%
#load dependencies / mount drive
import numpy as np
import os
import pickle
import random
import glob
import csv 
import json
import scipy
import math
import time
import ray
import psutil

from google.colab import drive
drive.mount('/content/drive')
# %cd /content/
# %mkdir training
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# mkdir: cannot create directory ‘training’: File exists

# %%
# Copy Given files to local instance for experiements

source_1 ='/content/drive/My\ Drive/Graphika/CF_docl_matrix.json'
source_2 = '/content/drive/My\ Drive/Graphika/AB_docl_matrix.json'

dest_1_sm = 'CF_docl_matrix.json'
dest_2_bg = 'AB_docl_matrix.json'

# !cp {source_1} {dest_1_sm}
# !cp {source_2} {dest_2_bg}

# %%
# Load Datasets to begin work.

with open(dest_1_sm) as sm_file:
  small_data = json.load(sm_file)

with open(dest_2_bg) as bg_file:
  big_data = json.load(bg_file)

# select which dataset to use
data = small_data

# %% [markdown]
# # Explore Dataset a little
# Ignore this section for the most part as most of this methodology was wrong. I just left it in here to show the thought process.

# %%
min_key = min(data, key=data.get)
max_key = max(data, key=data.get)

vals = data.values()

min_value , max_value = min(min(vals)) , max(max(vals))

# Free Up Ram
del(vals)

# Print results
print("Min Key   : ", min_key)
print("Max Key   : ", max_key)
print("Min Value : ", min_value)
print("Max Value : ", max_value)
# Out:
# Min Key   :  361947
# Max Key   :  90258
# Min Value :  548
# Max Value :  458812

# %%
print(data[min_key])
print(len(data[min_key]))
# Out:
# [548, 152169, 190255, 222175, 124431, 86197, 36805, 50957, 428532, 203431, 9081, 44897, 271469, 328841, 45201, 197238, 64553, 235978, 143434, 373893, 134996, 128647, 213559, 91382, 170726, 301005, 313223, 226829, 49963, 20219, 118275, 260609, 165826, 126117, 69598, 121716, 446748, 115577, 145914, 254245, 330779, 417329, 89733, 147882, 37007, 125720, 310983, 434592, 61823, 402703, 390006, 30015, 291370, 186187, 31673, 431201, 191107, 201580]
# 58

# %%
print(data[max_key])
print(len(data[max_key]))
# Out:
# [458812, 103526, 108271, 338600, 145010, 119980, 43725, 151104, 247248, 80336, 149168, 324791, 153145, 101581, 231770, 371982, 450051, 88236, 426575, 384434, 407624, 337672, 250094, 180586, 171408, 144318, 209298, 331484, 24570, 260580, 230994, 229740, 257640, 222347, 208852, 132673, 55181, 445236, 390348, 176446, 427758, 348430, 82322, 69616, 61461, 340975, 197573, 424561, 33830, 141336, 357942, 40054, 190337, 243554, 269538, 53049, 167878, 102988, 242488, 278618, 83505, 2206, 66514, 218112, 175427, 168202, 372502, 73856, 375436, 205673, 218309, 243819, 293466, 103239, 268483, 260315, 246984, 76315, 345706, 440928, 451870, 216243, 166192, 152557, 286155, 322254, 288843, 427495, 40790, 93466, 307878, 406335, 290202, 382256, 97926, 386041, 324357, 18556, 203951, 362509, 35646, 316510, 276244, 140288, 30107, 208954, 164833, 218765, 17663, 149559, 389154, 91228, 200594, 145873, 211774, 197904, 288128, 41732, 288865, 118328, 267990, 93530, 163575, 238745, 54266, 262547, 282179, 199282, 296707, 24167, 283362, 38641, 165675, 200633, 196830, 186775, 119272, 304795, 114903, 205863, 230345, 103831, 441291, 216470, 448418, 333814, 345540, 107582, 71285, 104176, 182950, 190188, 358608, 22538, 94923, 77474, 340189, 116719, 125890, 187602, 415608, 269948, 432292, 326083, 296330, 344391, 427295, 83512, 55277, 131461, 160284, 254605, 86995, 254919, 148967, 252729, 420609, 108058, 279660, 235950, 190582, 282946, 236457, 104678, 283448, 288187, 163717, 217585, 96726, 157112, 41330, 443908, 369101, 120900, 268490, 200011, 126626, 218510, 230101, 324938, 147878, 233961, 308160, 267878, 124957, 91904, 313131, 14082, 270252, 314479, 120830, 80537, 265261, 115263, 98379, 139428, 448670, 291727, 68285, 296267, 160013, 327812, 54545, 337153, 80907, 190332, 26215, 163747, 205735, 315706, 299389, 102370, 57181, 411372, 180507, 122106, 349058, 425125, 356826, 205847, 206490, 12691, 428093, 388761, 242091, 37398, 217388, 97099, 425985, 71907, 275946, 21782, 168557, 100727, 422081, 451174, 184146, 148019, 113669, 174665, 224799, 387230, 85114, 311915, 340218, 285498, 263971, 446114, 375874, 262367, 231428, 339666, 405543, 358053, 428039, 441648, 451869, 370275, 336950, 38278, 428654, 435955, 85448, 13473, 288886, 354188, 122237, 8130, 110690, 323110, 325908, 290846, 273914, 178642, 130239, 77390, 90306, 247258, 270094, 244537, 375770, 213799, 72298, 126574, 172732, 64220, 223044, 259023, 232618, 4900, 235993, 239774, 73309, 97712, 375314, 2111, 359869, 396890, 417702, 381244, 201926, 174046, 52499, 113482, 419212, 5398, 224245, 318127, 27850, 382268, 44107, 341766, 412808, 96369, 884, 345137, 133419, 337221, 122342, 8941, 137246, 59152, 167787, 58884, 76447, 228500, 238940, 76017, 15108, 248225, 379854, 455547, 117316, 270347, 334296, 236254, 185728, 360584, 218449, 317857, 325015, 192375, 13404, 369831, 238872, 261525, 162336, 86367, 270872, 437544, 404264, 295647, 258800, 243181, 183319, 32547, 284751, 79080, 403882]
# 379

# %%
# DOES NOT WORK AS THE ARRAYS ARE OF DIFFERENT LENGTH
r, m = scipy.stats.pearsonr(data[min_key], data[max_key])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-1e141527871a> in <module>()
#       1 # DOES NOT WORK AS THE ARRAYS ARE OF DIFFERENT LENGTH
# ----> 2 r, m = scipy.stats.pearsonr(data[min_key], data[max_key])
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3496     n = len(x)
#    3497     if n != len(y):
# -> 3498         raise ValueError('x and y must have the same length.')
#    3499
#    3500     if n < 2:
#
# ValueError: x and y must have the same length.

# %% [markdown]
# #Re-Factor dataset using sets and generate length of feature list to optimize calculations of PCC.
#
# Varibles for Big O calculations:
# 1. n = # of rows (index_values).
# 2. m = len([list of non-empty column names])
#
# Note: length of m varies.

# %%
id_list = [] # List of Anonymized Twitter ID's
data_set = {} # Set version of original data
max_feature = float('-inf') # maximum value in feature column
min_feature = float('inf') # minimum value in feature column - Might not  need this

# O(n * m)
for key in data: #O(n)
  id_list.append(key) #O(1)
  data_set[key] = set(data[key]) #O(m)
  max_feature = max(max_feature, max(data_set[key])) #O(m)
  min_feature = min(min_feature, min(data_set[key])) #O(m)

# Since min_feature == 0, add 1 to max_feature
max_feature+= 1

print("Total # of IDs:    ", len(id_list))
print("Feature Value Min: ", min_feature)
print("Feature Value Max: ", max_feature)
# Out:
# Total # of IDs:     1000
# Feature Value Min:  0
# Feature Value Max:  459316

# %%
@ray.remote
def calculate_r_value(set_a, set_b, max_feature):
  # length of set_a is the same as the sum of all 'x'
  sig_x = len(set_a)

  # mean of all set_a values = sum of all x / total feature count
  avg_x = sig_x / max_feature

  # do same calculations for 'y'
  sig_y = len(set_b)
  avg_y = sig_y / max_feature

  # Senario A: x = 1, y = 1  
  # -- Intersection Time Complexity (Avg): O(min(len(a), len(b)))
  sen_a = set_a.intersection(set_b) 
  numerator = len(sen_a) * ((1-avg_x) * (1-avg_y))
  denom_x = len(sen_a) * ((1-avg_x)**2)
  denom_y = len(sen_a) * ((1-avg_y)**2)

  # Senario B: x = 1, y = 0  
  # -- Difference Time Complexity (Avg): O(len(a))
  sen_b = set_a.difference(set_b)  
  numerator += len(sen_b) * ((1-avg_x) * (-avg_y))
  denom_x += len(sen_b) * ((1-avg_x)**2)
  denom_y += len(sen_b) * ((-avg_y)**2)

  # Senario C: x = 0, y = 1  
  # -- Difference Time Complexity (Avg): O(len(b))
  sen_c = set_b.difference(set_a)
  numerator += len(sen_c) * ((-avg_x) * (1-avg_y))
  denom_x += len(sen_c) * ((-avg_x)**2)
  denom_y += len(sen_c) * ((1-avg_y)**2)

  # Senario D: x = 0, y = 0  
  # -- Union Time Complexity (Avg): O(len(a) + len(b))
  sen_d = (max_feature - len(set_a.union(set_b)))
  numerator += sen_d * (avg_x * avg_y)
  denom_x += sen_d * (avg_x**2)
  denom_y += sen_d * (avg_y**2)

  denominator = math.sqrt(denom_x * denom_y)

  return 1 - (numerator / denominator)

# %%
num_cpus = psutil.cpu_count(logical=True)
num_cpus
# Out:
# 2

# %%
def create_PCC_matrix(max_feature, id_list, data_set):
  adjacency_matrix = np.zeros((len(id_list), len(id_list)))
  adjacency_list = {}

  ray_list = []

  #O(n * max(len(m)))
  for x in range(0,len(id_list)):
    for y in range(x+1, len(id_list)):
      r_val = calculate_r_value.remote(data_set[id_list[x]], data_set[id_list[y]], max_feature)
      
      ray_list.append(r_val)

  ray_list = ray.get(ray_list)

  counter = 0
  for x in range(0,len(id_list)):
    for y in range(x+1, len(id_list)):
      adjacency_matrix[x][y] = ray_list[counter]
      adjacency_list[(id_list[x], id_list[y])] = ray_list[counter]
      counter+=1

  return adjacency_list , adjacency_matrix

adjacency_list, adjacency_matrix = create_PCC_matrix(max_feature, id_list, data_set)

# %% [markdown]
# #TEST AREA DEFINITIONS

# %% [markdown]
# Method 'test_SLOW_version' defines a block of code that iterates through all features (max_features) and calculate the Pearson correlation distance with a O(max_features) runtime. For the small dataset max_features == 459315

# %%
def test_SLOW_version(data_set, id_list, x: int, y: int, callback=False) -> int:
  sig_x = len(data_set[id_list[x]])
  avg_x = sig_x / max_feature

  sig_y = len(data_set[id_list[y]])
  avg_y = sig_y / max_feature

  top = 0
  bottom_x = 0
  bottom_y = 0

  for i in range(0,max_feature): #O(max_feature) -- Very Expensive
    x_val = int(1 if i in data_set[id_list[x]] else 0)   #O(1) avg lookup for set 'in'
    y_val = int(1 if i in data_set[id_list[y]] else 0)   #O(1) avg lookup for set 'in'
    top += ((x_val - avg_x) * (y_val - avg_y))
    bottom_x += (x_val - avg_x)**2
    bottom_y += (y_val - avg_y)**2
  #print(top, " ", str((math.sqrt(bottom_x * bottom_y))))
  r_val = 1 - (top / (math.sqrt(bottom_x * bottom_y)))

  if callback == True:
    print("max_feature                       : ", max_feature)
    print("ID of first element in ID List    : ", id_list[x])
    print("ID of second element in ID List   : ", id_list[y])
    print("Pearson Coorelation Distance (1-r): ", r_val)

  return r_val

# %% [markdown]
# Method 'test_FAST_version' defines a block of code that utilizes sets and domain knowledge of sparse matricies to reduce runtime to O( len(set(x)) + len(set(y)).
#
# Where len(set(x)) is the length of the feature list of the first ID
#
# Where len(set(y)) is the length of the feature list of the second ID
#
# The above is drastically smaller and faster 'test_SLOW_version'

# %%
def test_FAST_version(set_a, set_b, x: int, y:int, callback=False) -> int:
  # length of set_a is the same as the sum of all 'x'
  sig_x = len(set_a)

  # mean of all set_a values = sum of all x / total feature count
  avg_x = sig_x / max_feature

  # do same calculations for 'y'
  sig_y = len(set_b)
  avg_y = sig_y / max_feature

  # Senario A: x = 1, y = 1  
  # -- Intersection Time Complexity (Avg): O(min(len(a), len(b)))
  sen_a = set_a.intersection(set_b) 
  numerator = len(sen_a) * ((1-avg_x) * (1-avg_y))
  denom_x = len(sen_a) * ((1-avg_x)**2)
  denom_y = len(sen_a) * ((1-avg_y)**2)

  # Senario B: x = 1, y = 0  
  # -- Difference Time Complexity (Avg): O(len(a))
  sen_b = set_a.difference(set_b)  
  numerator += len(sen_b) * ((1-avg_x) * (-avg_y))
  denom_x += len(sen_b) * ((1-avg_x)**2)
  denom_y += len(sen_b) * ((-avg_y)**2)

  # Senario C: x = 0, y = 1  
  # -- Difference Time Complexity (Avg): O(len(b))
  sen_c = set_b.difference(set_a)
  numerator += len(sen_c) * ((-avg_x) * (1-avg_y))
  denom_x += len(sen_c) * ((-avg_x)**2)
  denom_y += len(sen_c) * ((1-avg_y)**2)

  # Senario D: x = 0, y = 0  
  # -- Union Time Complexity (Avg): O(len(a) + len(b))
  sen_d = (max_feature - len(set_a.union(set_b)))
  numerator += sen_d * (avg_x * avg_y)
  denom_x += sen_d * (avg_x**2)
  denom_y += sen_d * (avg_y**2)

  denominator = math.sqrt(denom_x * denom_y)

  r_val = 1 - (numerator / denominator)
  #print(numerator, " ", denominator)
  if callback == True:
    print("max_feature                       : ", max_feature)
    print("ID of first element in ID List    : ", id_list[x])
    print("ID of second element in ID List   : ", id_list[y])
    print("Pearson Coorelation Distance (1-r): ", r_val)
  
  return r_val

# %% [markdown]
# #TEST AREA

# %%
x_range = 100
callback = False
fast_exec_time = []
slow_exec_time = []
error = []

for x in range(0,x_range):
  for y in range(x+1, x_range):
    start_time = time.time()
    a = test_SLOW_version(data_set, id_list, x, y, callback)
    slow_exec_time.append(time.time() - start_time)
    start_time = time.time()
    b = test_FAST_version(data_set[id_list[x]], data_set[id_list[y]], x, y, callback)
    fast_exec_time.append(time.time() - start_time)
    error.append(abs(a-b))

avg_error = sum(error) / len(error)
avg_fast = sum(fast_exec_time) / len(fast_exec_time)
avg_slow = sum(slow_exec_time) / len(slow_exec_time)

# %%
print("Average SLOW method time (ms): ", str(avg_slow*1000))
print("Average FAST method time (ms): ", str(avg_fast*1000))
print("")
print("Total   SLOW method time (ms): ", str(sum(slow_exec_time)*1000))
print("Total   FAST method time (ms): ", str(sum(fast_exec_time)*1000))
print("")
print("Average Error                : ", avg_error)
# Out:
# Average SLOW method time (ms):  348.57590135901864
# Average FAST method time (ms):  0.26386916035353536
#
# Total   SLOW method time (ms):  1725450.7117271423
# Total   FAST method time (ms):  1306.15234375
#
# Average Error                :  7.418963311254335e-14

# %%
adjacency_list, adjacency_matrix

with open('adj_matrix.csv', 'w') as fh:
    writer = csv.writer(fh, delimiter=',')
    writer.writerow(id_list)
    writer.writerows(enumerate(adjacency_matrix))

with open('adj_list.csv', 'w') as fh:
    writer = csv.writer(fh, delimiter=',')
    writer.writerows(enumerate(adjacency_list))
